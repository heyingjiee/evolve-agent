# %%
MEMORY_TYPES = ("user", "feedback", "project", "reference")

d = {
    "name1": {"age": 10},
    "name2": {"age": 10},
    "name3": {"age": 10},
}
print(d)
# Out:
# {'name1': {'age': 10}, 'name2': {'age': 10}, 'name3': {'age': 10}}
